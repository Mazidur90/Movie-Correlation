# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize']=(12,8)# Adjusts the coniguration of the plots we will create


df= pd.read_csv(r'C:\Users\Divyesh Jayswal\Downloads\movies.csv')
old=pd.read_csv(r'C:\Users\Divyesh Jayswal\Downloads\movies.csv')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
#lets see if there i sany missing data 

for col in df.columns:
    pct_missing =np.mean(df[col].isnull())
    print('{} - {}%'.format(col,pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
#data types for our columns

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
df['yearcorrevt'] = df['released'].astype(str).str[:4]
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# Create correct year column 
del df['yearcorrevt']  
df['year_correct'] = df['released'].astype(str).str[:5]  
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
old.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df = df.sort_values(by=['gross'],inplace=False,ascending= False)
old= df.sort_values(by=['gross'],inplace=False,ascending= False)

# %%
#to bring that side slider navigate through data easily
pd.set_option('display.max_rows',None)
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country       budget  \
# ...

# %%
#drop any duplicates


 df['company'] = df['company'].drop_duplicates().sort_values(ascending= False)
df.drop_duplicates()
# Out:
#   File "C:\Users\Divyesh Jayswal\AppData\Local\Temp\ipykernel_3528\2582049708.py", line 4
#     df['company'] = df['company'].drop_duplicates().sort_values(ascending= False)
#     ^
# IndentationError: unexpected indent

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# making an unclearified assumption 
# Budget high corelation 
# company will have a high corelation

# %%
# Scater plot with budget vs gross

plt.scatter(x= df['budget'], y=df['gross'])
plt.title('Budget vs Gross Earnings')
plt.xlabel('Gross Earnings (In Millions)')
plt.ylabel('Budget for film (In Millions)')
plt.show

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
#plot the budget vs gross using seaborn

sns.regplot(x='budget',y='gross',data=df,scatter_kws = {"color" : "red"},line_kws={"color":"blue"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
df.corr()
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.329321  0.257486  0.120811
# score    0.097995  1.000000  0.409182  0.076254  0.186258  0.399451
# votes    0.222945  0.409182  1.000000  0.442429  0.630757  0.309212
# budget   0.329321  0.076254  0.442429  1.000000  0.740395  0.320447
# gross    0.257486  0.186258  0.630757  0.740395  1.000000  0.245216
# runtime  0.120811  0.399451  0.309212  0.320447  0.245216  1.000000

# %%
df.corr(method='kendall')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.067652  0.331465  0.224120  0.200618  0.097184
# score    0.067652  1.000000  0.300115 -0.000566  0.086046  0.283611
# votes    0.331465  0.300115  1.000000  0.353702  0.548899  0.198240
# budget   0.224120 -0.000566  0.353702  1.000000  0.512637  0.235483
# gross    0.200618  0.086046  0.548899  0.512637  1.000000  0.168933
# runtime  0.097184  0.283611  0.198240  0.235483  0.168933  1.000000

# %%
#high correlaton between budget and score

# %%
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot= True)
plt.title('Correlation_matrix')
plt.xlabel('Movie features')
plt.ylabel('Movie features')
plt.show()

# %%
#looks at company 
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df_numerised= df

for col_name in df_numerised.columns:
     if (df_numerised[col_name].dtype=='object'):
        df_numerised[col_name]= df_numerised[col_name].astype('category')
        df_numerised[col_name]= df_numerised[col_name].cat.codes
df_numerised.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3   286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000.0      1054     521
#
#    star  country      budget        gross  company  runtime  yearcorrevt
# 0  1047       54  19000000.0   46998772.0     2319    146.0           14
# 1   327       55   4500000.0   58853106.0      731    104.0           13
# 2  1745       55  18000000.0  538375067.0     1540    124.0           14
# 3  2246       55   3500000.0   83453539.0     1812     88.0           13
# 4   410       55   6000000.0   39846344.0     1777     98.0           13

# %%
correlation_matrix = df_numerised.corr()
sns.heatmap(correlation_matrix, annot= True)
plt.title('Correlation_matrix')
plt.xlabel('Movie features')
plt.ylabel('Movie features')
plt.show()

# %%
df_numerised.corr()
# Out:
#                  name    rating     genre      year  released     score  \
# name         1.000000 -0.008069  0.016355  0.011453 -0.011311  0.017097
# rating      -0.008069  1.000000  0.072423  0.008779  0.016613 -0.001314
# genre        0.016355  0.072423  1.000000 -0.081261  0.029822  0.027965
# year         0.011453  0.008779 -0.081261  1.000000 -0.000695  0.097995
# released    -0.011311  0.016613  0.029822 -0.000695  1.000000  0.042788
# score        0.017097 -0.001314  0.027965  0.097995  0.042788  1.000000
# votes        0.013088  0.033225 -0.145307  0.222945  0.016097  0.409182
# director     0.009079  0.019483 -0.015258 -0.020795 -0.001478  0.009559
# writer       0.009081 -0.005921  0.006567 -0.008656 -0.002404  0.019416
# star         0.006472  0.013405 -0.005477 -0.027242  0.015777 -0.001609
# country     -0.010737  0.081244 -0.037615 -0.070938 -0.020427 -0.133348
# budget       0.023970 -0.176002 -0.356564  0.329321  0.014683  0.076254
# ...

# %%
correlation_mat =df_numerised.corr()
corr_pairs= correlation_mat.unstack()
corr_pairs
# Out:
# name         name           1.000000
#              rating        -0.008069
#              genre          0.016355
#              year           0.011453
#              released      -0.011311
#              score          0.017097
#              votes          0.013088
#              director       0.009079
#              writer         0.009081
#              star           0.006472
#              country       -0.010737
#              budget         0.023970
#              gross          0.005533
#              company        0.009211
#              runtime        0.010392
#              yearcorrevt   -0.011725
# rating       name          -0.008069
#              rating         1.000000
#              genre          0.072423
#              year           0.008779
#              released       0.016613
#              score         -0.001314
#              votes          0.033225
#              director       0.019483
#              writer        -0.005921
# ...

# %%
sorted_pairs = corr_pairs.sort_values()
sorted_pairs
# Out:
# genre        budget        -0.356564
# budget       genre         -0.356564
# genre        gross         -0.235650
# gross        genre         -0.235650
# budget       rating        -0.176002
# rating       budget        -0.176002
# votes        genre         -0.145307
# genre        votes         -0.145307
# country      score         -0.133348
# score        country       -0.133348
# rating       gross         -0.107339
# gross        rating        -0.107339
# genre        year          -0.081261
# year         genre         -0.081261
# runtime      country       -0.078412
# country      runtime       -0.078412
# company      genre         -0.071067
# genre        company       -0.071067
# country      year          -0.070938
# year         country       -0.070938
# genre        runtime       -0.052711
# runtime      genre         -0.052711
# budget       writer        -0.039451
# writer       budget        -0.039451
# country      genre         -0.037615
# ...

# %%
high_corr = sorted_pairs[(sorted_pairs) > 0.5]
high_corr
# Out:
# votes        gross          0.630757
# gross        votes          0.630757
#              budget         0.740395
# budget       gross          0.740395
# yearcorrevt  released       0.993694
# released     yearcorrevt    0.993694
# name         name           1.000000
# company      company        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# country      country        1.000000
# star         star           1.000000
# writer       writer         1.000000
# director     director       1.000000
# votes        votes          1.000000
# score        score          1.000000
# released     released       1.000000
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrevt  yearcorrevt    1.000000
# dtype: float64

# %%
#-----------------Final Comments-----------------
# from the above data, it has been proven that the assumption i made before was wrong! The votes and budget has the highest correlation to gross earnings 
#company has lowest correlations
